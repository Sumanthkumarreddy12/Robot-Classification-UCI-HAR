# %%
# !wget https://archive.ics.uci.edu/static/public/240/human+activity+recognition+using+smartphones.zip
# Out:
# --2026-02-25 08:07:56--  https://archive.ics.uci.edu/static/public/240/human+activity+recognition+using+smartphones.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘human+activity+recognition+using+smartphones.zip.1’
#
# human+activity+reco     [              <=>   ]  58.18M  18.0MB/s    in 3.2s
#
# 2026-02-25 08:08:00 (18.0 MB/s) - ‘human+activity+recognition+using+smartphones.zip.1’ saved [61005872]

# %%
# !unzip human+activity+recognition+using+smartphones.zip
# Out:
# Archive:  human+activity+recognition+using+smartphones.zip
# replace UCI HAR Dataset.names? [y]es, [n]o, [A]ll, [N]one, [r]ename: UCI HAR Dataset
# error:  invalid response [UCI HAR D]
# replace UCI HAR Dataset.names? [y]es, [n]o, [A]ll, [N]one, [r]ename: error:  invalid response [ataset]
# replace UCI HAR Dataset.names? [y]es, [n]o, [A]ll, [N]one, [r]ename: r
# new name: UCI HAR Dataset
#  extracting: UCI HAR Dataset
# replace UCI HAR Dataset.zip? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#  extracting: UCI HAR Dataset.zip

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'human+activity+recognition+using+smartphones.zip.1', 'UCI HAR Dataset.zip', 'UCI HAR Dataset.names', 'UCI HAR Dataset', 'human+activity+recognition+using+smartphones.zip', 'UCI HAR Dataset (1).zip', 'human+activity+recognition+using+smartphones (1).zip', 'sample_data']

# %%
import pandas as pd

data = pd.read_csv("UCI HAR Dataset/train/X_train.txt",
                   sep=r'\s+', # Using a raw string to fix the SyntaxWarning
                   header=None)

print("Dataset Shape:", data.shape)
data.head()
# Out:
# Dataset Shape: (7352, 561)
#         0         1         2         3         4         5         6    \
# 0  0.288585 -0.020294 -0.132905 -0.995279 -0.983111 -0.913526 -0.995112
# 1  0.278419 -0.016411 -0.123520 -0.998245 -0.975300 -0.960322 -0.998807
# 2  0.279653 -0.019467 -0.113462 -0.995380 -0.967187 -0.978944 -0.996520
# 3  0.279174 -0.026201 -0.123283 -0.996091 -0.983403 -0.990675 -0.997099
# 4  0.276629 -0.016570 -0.115362 -0.998139 -0.980817 -0.990482 -0.998321
#
#         7         8         9    ...       551       552       553       554  \
# 0 -0.983185 -0.923527 -0.934724  ... -0.074323 -0.298676 -0.710304 -0.112754
# 1 -0.974914 -0.957686 -0.943068  ...  0.158075 -0.595051 -0.861499  0.053477
# 2 -0.963668 -0.977469 -0.938692  ...  0.414503 -0.390748 -0.760104 -0.118559
# 3 -0.982750 -0.989302 -0.938692  ...  0.404573 -0.117290 -0.482845 -0.036788
# 4 -0.979672 -0.990441 -0.942469  ...  0.087753 -0.351471 -0.699205  0.123320
#
# ...

# %%
# !unzip -o 'UCI HAR Dataset.zip'
# Out:
# Archive:  UCI HAR Dataset.zip
#    creating: UCI HAR Dataset/
#   inflating: UCI HAR Dataset/.DS_Store
#    creating: __MACOSX/
#    creating: __MACOSX/UCI HAR Dataset/
#   inflating: __MACOSX/UCI HAR Dataset/._.DS_Store
#   inflating: UCI HAR Dataset/activity_labels.txt
#   inflating: __MACOSX/UCI HAR Dataset/._activity_labels.txt
#   inflating: UCI HAR Dataset/features.txt
#   inflating: __MACOSX/UCI HAR Dataset/._features.txt
#   inflating: UCI HAR Dataset/features_info.txt
#   inflating: __MACOSX/UCI HAR Dataset/._features_info.txt
#   inflating: UCI HAR Dataset/README.txt
#   inflating: __MACOSX/UCI HAR Dataset/._README.txt
#    creating: UCI HAR Dataset/test/
#    creating: UCI HAR Dataset/test/Inertial Signals/
#   inflating: UCI HAR Dataset/test/Inertial Signals/body_acc_x_test.txt
#    creating: __MACOSX/UCI HAR Dataset/test/
#    creating: __MACOSX/UCI HAR Dataset/test/Inertial Signals/
#   inflating: __MACOSX/UCI HAR Dataset/test/Inertial Signals/._body_acc_x_test.txt
# ...

# %%
import os
print(os.listdir('UCI HAR Dataset'))
# Out:
# ['features_info.txt', 'features.txt', 'README.txt', 'activity_labels.txt', 'train', '.DS_Store', 'test']

# %%
# Extract the inner zip file
# !unzip -o 'UCI HAR Dataset.zip'
# Out:
# Archive:  UCI HAR Dataset.zip
#   inflating: UCI HAR Dataset/.DS_Store
#   inflating: __MACOSX/UCI HAR Dataset/._.DS_Store
#   inflating: UCI HAR Dataset/activity_labels.txt
#   inflating: __MACOSX/UCI HAR Dataset/._activity_labels.txt
#   inflating: UCI HAR Dataset/features.txt
#   inflating: __MACOSX/UCI HAR Dataset/._features.txt
#   inflating: UCI HAR Dataset/features_info.txt
#   inflating: __MACOSX/UCI HAR Dataset/._features_info.txt
#   inflating: UCI HAR Dataset/README.txt
#   inflating: __MACOSX/UCI HAR Dataset/._README.txt
#   inflating: UCI HAR Dataset/test/Inertial Signals/body_acc_x_test.txt
#   inflating: __MACOSX/UCI HAR Dataset/test/Inertial Signals/._body_acc_x_test.txt
#   inflating: UCI HAR Dataset/test/Inertial Signals/body_acc_y_test.txt
#   inflating: __MACOSX/UCI HAR Dataset/test/Inertial Signals/._body_acc_y_test.txt
#   inflating: UCI HAR Dataset/test/Inertial Signals/body_acc_z_test.txt
# ...

# %%
import os
# List the contents of the newly extracted directory to verify
print(os.listdir('UCI HAR Dataset'))
# Out:
# ['features_info.txt', 'features.txt', 'README.txt', 'activity_labels.txt', 'train', '.DS_Store', 'test']

# %%
import os
import shutil

# Remove previously extracted files/directories to ensure a clean slate

if os.path.exists('UCI HAR Dataset'):
    if os.path.isdir('UCI HAR Dataset'):
        shutil.rmtree('UCI HAR Dataset')
    else:
        os.remove('UCI HAR Dataset')

if os.path.exists('UCI HAR Dataset.zip'):
    if os.path.isdir('UCI HAR Dataset.zip'):
        shutil.rmtree('UCI HAR Dataset.zip')
    else:
        os.remove('UCI HAR Dataset.zip')

print('Cleaned up previous extraction attempts.')
# Out:
# Cleaned up previous extraction attempts.

# %%
# Re-extract the zip file, forcing overwrite to avoid prompts
# !unzip -o human+activity+recognition+using+smartphones.zip
# Out:
# Archive:  human+activity+recognition+using+smartphones.zip
#  extracting: UCI HAR Dataset.names
#  extracting: UCI HAR Dataset.zip

# %%
altitude = data.iloc[:, 0]   # proxy altitude
velocity = data.iloc[:, 1]   # proxy velocity

print("Sample altitude values:")
print(altitude.head())
# Out:
# Sample altitude values:
# 0    0.288585
# 1    0.278419
# 2    0.279653
# 3    0.279174
# 4    0.276629
# Name: 0, dtype: float64

# %%
def classify_robot(alt):
    if alt > 0:
        return "Aerial Autonomous Robot"
    else:
        return "Ground Robot"

data['Robot_Type'] = altitude.apply(classify_robot)

print(data[['Robot_Type']].head())
# Out:
#                 Robot_Type
# 0  Aerial Autonomous Robot
# 1  Aerial Autonomous Robot
# 2  Aerial Autonomous Robot
# 3  Aerial Autonomous Robot
# 4  Aerial Autonomous Robot
